# %% [markdown]
# # Time Series Analysis in Medicine and Biology
# ## Practical Course — University of Tübingen · PfeiferLab
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShamsaraE/time-series-medicine-biology/blob/main/session-projects/04_dynamic_regression_ridge_elasticnet_rf.ipynb)
#
# ---
#
# # Session Project 04 — Dynamic Regression with Variants (Germany)
#
# **Goal:** model the weekly German COVID-19 case curve as a **dynamic regression** and compare
# linear and nonlinear learners under honest, time-aware evaluation.
#
# **In this project you will:**
# 1. Build the weekly modelling dataset (reuse your construction from Session Project 01/03).
# 2. Establish **baselines** (persistence, seasonal-naive).
# 3. Fit and tune **Ridge**, **ElasticNet**, and **Random Forest** with **nested / time-series CV**.
# 4. Extract and interpret **feature importance** for each model.
# 5. Compare all models on **MAE and RMSE** and write a short structured report.
#
# **Model.** With $z_t = \log(1+\text{cases}_t)$:
#
# $$z_t = \phi_1 z_{t-1}+\phi_2 z_{t-2}+\phi_3 z_{t-3} + \beta_V V_{t-2} + \beta_S S_t + \beta_{VS}(V_{t-2}\cdot C_t) + \sum_{k=1}^{K-1}\gamma_k \mathbb{1}\{C_t = c_k\} + \varepsilon_t.$$
#
# **Data:** OWID COVID-19 data + ECDC variants, Germany (loaded live; reuse Session Project 01).
#
# **What you submit:** a clean notebook with run cells, the model-comparison table, feature-importance
# plots, and a short written report (which model wins, and why).
#
# > Fill in every `# Your code here` / `# like before!` block yourself.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

from sklearn.linear_model import Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

SEED = 42
np.random.seed(SEED)

# %% [markdown]
# ## Step 1 — Load Weekly Dataset
#
# Reuse the weekly dataset construction from the previous notebook.
#
# Make sure you end up with:
#
# - df_model
# - X (features)
# - y (target)

# %%
# Your code here

# %% [markdown]
# ## Step 2 — Baselines
#
# Compute:
# Baseline

# %%
# Your code here

# %% [markdown]
# ## Step 3 — Ridge Regression

# %%
# Build a Ridge pipeline as in Session Project 03 (StandardScaler + Ridge,
# tuned with TimeSeriesSplit). Your code here:

# %% [markdown]
# ## Step 4 — ElasticNet
#
# ElasticNet combines L1 and L2:
#
# - L1 performs feature selection
# - L2 stabilizes estimates

# %%
# Your code here

# %% [markdown]
# ## Step 5 — Nonlinear Model (Random Forest)

# %%
# your code here

# %% [markdown]
# ## Step 6 — Feature Importance
#
# For:
#
# - Ridge → standardized coefficients
# - ElasticNet → coefficients (many may be zero)
# - Random Forest → feature_importances_

# %%
# Your code here

# %% [markdown]
# ## Step 7 — Model Comparison (metrics)

# %%
# Your code here
